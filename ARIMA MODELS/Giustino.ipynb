# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from sklearn.metrics import mean_squared_error
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
from times_series_workflow import *
from clean_data import clean
import pandas_ta as ta

# %%
#loading data
data=pd.read_csv("../data/technical analysis/ta_btc.csv")

# %%
data.head()
# Out:
#    Unnamed: 0            open_time     open     high      low    close  \
# 0           0  2020-01-01 00:00:00  7195.24  7245.00  7175.46  7224.21
# 1           1  2020-01-01 06:00:00  7224.24  7237.73  7180.00  7197.20
# 2           2  2020-01-01 12:00:00  7197.20  7255.00  7196.15  7236.83
# 3           3  2020-01-01 18:00:00  7237.02  7246.72  7175.15  7200.85
# 4           4  2020-01-02 00:00:00  7200.77  7212.50  7116.70  7138.93
#
#         volume     close_time           qav  num_trades  ...  %D  \
# 0  3646.232354  1577858399999  2.631450e+07       44901  ... NaN
# 1  4415.466238  1577879999999  3.182890e+07       51073  ... NaN
# 2  5443.680806  1577901599999  3.934948e+07       55857  ... NaN
# 3  3287.008767  1577923199999  2.372158e+07       42179  ... NaN
# 4  5561.311699  1577944799999  3.980317e+07       60466  ... NaN
#
#    MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  conversion_line  base_line  \
# 0           NaN            NaN            NaN              NaN        NaN
# 1           NaN            NaN            NaN              NaN        NaN
# 2           NaN            NaN            NaN              NaN        NaN
# 3           NaN            NaN            NaN              NaN        NaN
# 4           NaN            NaN            NaN              NaN        NaN
#
#    lead_span_A  lead_span_B  lagging_span  CCI
# 0          NaN          NaN       8077.68  NaN
# 1          NaN          NaN       8055.98  NaN
# 2          NaN          NaN       7941.83  NaN
# 3          NaN          NaN       7878.56  NaN
# 4          NaN          NaN       7798.60  NaN
#
# [5 rows x 25 columns]

# %%
data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
data = data.dropna().copy()

# %%
data=data.sort_values('open_time')

# %%
data=data.reset_index(drop=True)

# %%
data.head()
# Out:
#              open_time     open     high      low    close        volume  \
# 0  2020-02-29 18:00:00  8651.76  8676.00  8523.55  8523.61   6909.498159
# 1  2020-03-01 00:00:00  8523.61  8675.00  8511.11  8586.83   8957.065560
# 2  2020-03-01 06:00:00  8586.50  8650.00  8518.00  8648.37   8106.169400
# 3  2020-03-01 12:00:00  8647.42  8750.00  8454.57  8500.00  15720.950431
# 4  2020-03-01 18:00:00  8499.87  8591.82  8411.00  8531.88  11108.016388
#
#       close_time           qav  num_trades  taker_base_vol  ...         %D  \
# 0  1583020799999  5.959308e+07       82883     3299.843644  ...  20.087563
# 1  1583042399999  7.695507e+07      107810     4248.999557  ...  20.054477
# 2  1583063999999  6.943837e+07       93946     4135.089393  ...  24.896536
# 3  1583085599999  1.348397e+08      159233     7678.727169  ...  25.324145
# 4  1583107199999  9.449621e+07      111030     5775.552747  ...  23.534682
#
#    MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  conversion_line  base_line  \
# 0   -256.142004      -3.432722    -252.709282          9060.00   9410.000
# 1   -250.569113       1.712135    -252.281248          9060.00   9359.590
# 2   -238.438226      11.074418    -249.512644          9060.00   9352.485
# 3   -238.052508       9.168108    -247.220617          8935.51   9347.500
# 4   -232.494325      11.781033    -244.275358          8894.22   9330.500
#
#    lead_span_A  lead_span_B  lagging_span         CCI
# 0       9862.5       8286.5       8741.53 -119.532854
# 1       9862.5       8286.5       8309.91  -95.418354
# 2       9862.5       8286.5       8033.31  -74.707898
# 3       9862.5       8286.5       7932.05  -89.605892
# 4       9862.5       8286.5       7804.92 -119.003329
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (4715, 24)

# %%
# Let's define the global variables of our dataset
TARGET = 'close'
N_TARGETS = 1
N_FEATURES = 19

# %%
X=data.drop(columns=["open_time","close"])
y=data["close"]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler(feature_range=(0,1))
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.06377653, 0.05531195, 0.07464702, ..., 0.03433166, 0.06517971,
#         0.39435238],
#        [0.06177636, 0.05529629, 0.07445117, ..., 0.03433166, 0.05844281,
#         0.42326638],
#        [0.06275795, 0.05490479, 0.07455965, ..., 0.03433166, 0.05412553,
#         0.44809884],
#        ...,
#        [0.34781813, 0.34163618, 0.36268486, ..., 0.39398912, 0.36610747,
#         0.51043691],
#        [0.34780439, 0.35003492, 0.36235441, ..., 0.39398912, 0.36103037,
#         0.74931291],
#        [0.35620496, 0.34894951, 0.36876048, ..., 0.39398912, 0.36100353,
#         0.73564054]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3772, 22)
# (3772,)
# (943, 22)
# (943,)

# %%
import numpy as np

y_train = y_train.values.reshape(-1, 1)

# %%
# def create_dataset(dataset, time_step=1):
#     dataX, dataY = [], []
#     for i in range(len(dataset)-time_step-1):
#         a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
#         dataX.append(a)
#         dataY.append(dataset[i + time_step, 0])
#     return np.array(dataX), np.array(dataY)

# %%
# time_step = 15
# X_train= create_dataset(X_train, time_step)
# y_train = create_dataset(y_train, time_step)
# X_test = create_dataset(X_test, time_step)
# y_test = create_dataset(y_test, time_step)

# print("X_train: ", X_train.shape)
# print("y_train: ", y_train.shape)
# print("X_test: ", X_test.shape)
# print("y_test", y_test.shape)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.layers import Masking
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import optimizers, metrics
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.layers import LSTM


# # –– Data
# X_train,X_test = pad_sequences(X_train,X_test, dtype='float32', padding='post', value=-1000)
# # X.shape == (3,4,3)

# # –– Model
# model = Sequential()
# model.add(layers.Masking(mask_value=-1000, input_shape=(3987,22)))
# model.add(LSTM(10,input_shape=(None,1),activation="relu"))
# model.add(layers.Dense(10, activation='relu'))
# model.add(layers.Dense(1, activation='linear'))

# # –– Compilation
# model.compile(loss='mse', 
#               optimizer='adam') 

# # –– Fit
# model.fit(X, y);
# Out:
# 2023-06-12 11:53:05.064234: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-12 11:53:06.261479: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-12 11:53:06.261648: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-12 11:53:06.546670: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-06-12 11:53:10.636872: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-12 11:53:10.637308: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-12 11:53:10.637323: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import keras
def init_model_2(input_shape):
    inputs = keras.Input(shape=input_shape)
    hidden = keras.layers.LSTM(64)(inputs)
    output = keras.layers.Dense(1)(hidden)
    model = keras.Model(inputs=inputs, outputs=output)
    return model

# %%
def init_model(X_train,y_train):
    
    # $CHALLENGIFY_BEGIN    
        
    # 1 - RNN architecture
    # ======================  
    model = Sequential()
    
    ## 1.1 - Recurrent Layer
    model.add(layers.LSTM(64, 
                          activation='tanh', 
                          return_sequences = True,
                          kernel_regularizer=L1L2(l1=0.05, l2=0.05),
                          input_shape=(None,22)
                          ))
    ## 1.2 - Predictive Dense Layers
    #output_length = y_train.shape[1]
    model.add(layers.Dense(1, activation='linear'))

    # 2 - Compiler
    # ======================    
    adam = optimizers.Adam(learning_rate=0.02)    
    model.compile(loss='mse', optimizer=adam, metrics=["mae"])
    
    
    
    return model
    # $CHALLENGIFY_END

# %%
def plot_history(history):
    
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    # --- LOSS: MSE --- 
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('MSE')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Validation'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- METRICS:MAE ---
    
    ax[1].plot(history.history['mae'])
    ax[1].plot(history.history['val_mae'])
    ax[1].set_title('MAE')
    ax[1].set_ylabel('MAE')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Validation'], loc='best')
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
                        
    return ax

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping

def fit_model(model, verbose=1):

    # $CHALLENGIFY_BEGIN
    es = EarlyStopping(monitor = "val_loss",
                      patience = 3,
                      mode = "min",
                      restore_best_weights = True)

    print(X_train.shape)
    history = model.fit(X_train, y_train,
                        shuffle = False,
                        batch_size = 32,
                        epochs = 50,
                        callbacks = [es],
                        verbose = verbose)

    return model, history
    # $CHALLENGIFY_END

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3772, 22, 1)
# (3772, 1)

# %%
# 1 - Initialising the RNN model
# ====================================
X_train_reshaped = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
#X_train=X_train.reshape(3772,22,1)
model = init_model_2((X_train_reshaped.shape[1],1))
model.summary()
adam = optimizers.Adam(learning_rate=0.02)    
model.compile(loss='mse', optimizer=adam)


# 2 - Training
# ====================================
model, history = fit_model(model)
# Out:
# 2023-06-12 11:53:52.351162: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-12 11:53:52.352782: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-12 11:53:52.353150: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (Yass): /proc/driver/nvidia/version does not exist
# 2023-06-12 11:53:52.357410: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 22, 1)]           0
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# (3772, 22, 1)
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 1130601600.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 8s 34ms/step - loss: 1130601600.0000
# Epoch 2/50
# 117/118 [============================>.] - ETA: 0s - loss: 1124386816.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 28ms/step - loss: 1122126208.0000
# Epoch 3/50
# 118/118 [==============================] - ETA: 0s - loss: 1113815552.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 27ms/step - loss: 1113815552.0000
# Epoch 4/50
# 118/118 [==============================] - ETA: 0s - loss: 1105589120.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 27ms/step - loss: 1105589120.0000
# Epoch 5/50
# 117/118 [============================>.] - ETA: 0s - loss: 1099663360.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 27ms/step - loss: 1097431936.0000
# Epoch 6/50
# 118/118 [==============================] - ETA: 0s - loss: 1089336960.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 4s 30ms/step - loss: 1089336960.0000
# Epoch 7/50
# 117/118 [============================>.] - ETA: 0s - loss: 1083513600.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 28ms/step - loss: 1081301376.0000
# Epoch 8/50
# 117/118 [============================>.] - ETA: 0s - loss: 1075525504.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 29ms/step - loss: 1073322880.0000
# Epoch 9/50
# 118/118 [==============================] - ETA: 0s - loss: 1065399808.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 4s 32ms/step - loss: 1065399808.0000
# Epoch 10/50
# 118/118 [==============================] - ETA: 0s - loss: 1057371520.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 4s 31ms/step - loss: 1057371520.0000
# Epoch 11/50
# 117/118 [============================>.] - ETA: 0s - loss: 1051325376.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 4s 30ms/step - loss: 1049151168.0000
# Epoch 12/50
# 117/118 [============================>.] - ETA: 0s - loss: 1043288000.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 4s 30ms/step - loss: 1041123776.0000
# Epoch 13/50
# 117/118 [============================>.] - ETA: 0s - loss: 1035353088.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 29ms/step - loss: 1033198656.0000
# Epoch 14/50
# 116/118 [============================>.] - ETA: 0s - loss: 1025428416.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 25ms/step - loss: 1025349760.0000
# Epoch 15/50
# 117/118 [============================>.] - ETA: 0s - loss: 1019702656.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 24ms/step - loss: 1017567680.0000
# Epoch 16/50
# 117/118 [============================>.] - ETA: 0s - loss: 1011971456.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 27ms/step - loss: 1009846208.0000
# Epoch 17/50
# 117/118 [============================>.] - ETA: 0s - loss: 1004296960.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 26ms/step - loss: 1002181312.0000
# Epoch 18/50
# 117/118 [============================>.] - ETA: 0s - loss: 996676864.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 25ms/step - loss: 994570880.0000
# Epoch 19/50
# 117/118 [============================>.] - ETA: 0s - loss: 989109504.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s 28ms/step - loss: 987013056.0000
# Epoch 20/50
# 117/118 [============================>.] - ETA: 0s - loss: 981592768.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 118/118 [==============================] - 3s